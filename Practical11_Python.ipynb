# %%
#PySpark
#Create RDD in PySpark
# Parallelized Collections
data = [1, 2, 3, 4, 5]
distData = sc.parallelize(data)

# %%
#External datasets
distFile = sc.textFile("/FileStore/tables/txtfile.txt")
distFile
# Out:
# Out[71]: /FileStore/tables/txtfile.txt MapPartitionsRDD[181] at textFile at <unknown>:0

# %%
#Create from another RDD
rdd = sc.parallelize([20000,100000,3000])
rd_new = rdd.map(lambda x : x + 100)
rd_new.collect()
# Out:
# Out[57]: [20100, 100100, 3100]

# %%
#Writ a code in Spark to get the word count of the “textfile.txt”
splitdata = distFile.flatMap(lambda line:line.split(" "))
mapdata = splitdata.map(lambda word:(word,1)) #assign key to each word
reducedata = mapdata.reduceByKey(lambda c1,c2:c1 + c2) #return RDD object
print(reducedata.collect())
# Out:
# [('lion', 3), ('tiger', 2), ('cat', 3), ('mouse', 1), ('', 1), ('ant', 2), ('dod', 1), ('deer', 2), ('dog', 4), ('elephant', 1)]

# %%
# Spark SQL
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Working with data from the web
#import urllib.request
#urllib.request.urlretrieve("http://kdd.org/cupfiles/KDDCupData/1999/kddcup.data_10_percent.zip", "/tmp/kddcup_data.zip")
#dbutils.fs.mv("file:/tmp/kddcup_data.zip", "dbfs:/kdd/kddcup_data.zip")
#display(dbutils.fs.ls("dbfs:/kdd"))

# %%
#Build the KDD dataset
import urllib.request
raw_rdd = sc.textFile("/FileStore/tables/kddcupdata_10_percent.txt").cache()
#raw_rdd = sc.textFile(data_file).cache()
raw_rdd.take(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-806274398607603> in <module>
#       3 raw_rdd = sc.textFile("/FileStore/tables/kddcupdata_10_percent.txt").cache()
#       4 #raw_rdd = sc.textFile(data_file).cache()
# ----> 5 raw_rdd.take(5)
#
# /databricks/spark/python/pyspark/rdd.py in take(self, num)
#    1565         """
#    1566         items = []
# -> 1567         totalParts = self.getNumPartitions()
#    1568         partsScanned = 0
#    1569
#
# /databricks/spark/python/pyspark/rdd.py in getNumPartitions(self)
#     466         2
#     467         """
# --> 468         return self._jrdd.partitions().size()
#     469
#     470     def filter(self, f):
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %%
#Build a Spark DataFrame on our data
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)
sqlContext
# Out:
# Out[63]: <pyspark.sql.context.SQLContext at 0x7f9159b392e0>

# %%
csv_rdd = raw_rdd.map(lambda row: row.split(","))
print(csv_rdd.take(2))
print(type(csv_rdd))
len(csv_rdd.take(1)[0]) # Check the total number of features (columns)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-2038132470181162> in <module>
#       1 csv_rdd = raw_rdd.map(lambda row: row.split(","))
# ----> 2 print(csv_rdd.take(2))
#       3 print(type(csv_rdd))
#       4 len(csv_rdd.take(1)[0]) # Check the total number of features (columns)
#
# /databricks/spark/python/pyspark/rdd.py in take(self, num)
#    1565         """
#    1566         items = []
# -> 1567         totalParts = self.getNumPartitions()
#    1568         partsScanned = 0
#    1569
#
# /databricks/spark/python/pyspark/rdd.py in getNumPartitions(self)
#    2969
#    2970     def getNumPartitions(self):
# -> 2971         return self._prev_jrdd.partitions().size()
#    2972
#    2973     @property
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
# ...

# %%
from pyspark.sql import Row
parsed_rdd = csv_rdd.map(lambda r: Row(
 duration=int(r[0]),
 protocol_type=r[1],
 service=r[2],
 flag=r[3],
 src_bytes=int(r[4]),
 dst_bytes=int(r[5]),
 wrong_fragment=int(r[7]),
 urgent=int(r[8]),
 hot=int(r[9]),
 num_failed_logins=int(r[10]),
 num_compromised=int(r[12]),
 su_attempted=r[14],
 num_root=int(r[15]),
 num_file_creations=int(r[16]),
 label=r[-1]
 )
)
parsed_rdd.take(5)

# %%
ls "/FileStore/tables/"
# Out:
# ls: cannot access '/FileStore/tables/': No such file or directory

# %%
# %cd "/FileStore/tables/"
# Out:
# [Errno 2] No such file or directory: '/FileStore/tables/'
# /databricks/driver
